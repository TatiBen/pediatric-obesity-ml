# %%
print("I am ready to do research")
# Out:
# I am ready to do research

# %%
import pands as pd 
print(pd._ _ version_ _)
# Out:
#   Cell In[2], line 2
#     print(pd._ _ version_ _)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
print(pd._ _version_ _)
# Out:
#   Cell In[3], line 2
#     print(pd._ _version_ _)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("matplotlib:",plt.matplotlib._ _version_ _)
# Out:
#   Cell In[4], line 1
#     print("matplotlib:",plt.matplotlib._ _version_ _)
#                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd 
import numpy as np 
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
print ("pandas:",pd.__version__) 
print("numpy:",np.__version__)
print("matplotlib:", matplotlib.__version__) 
print("seaborn:", sns.__version__)
# Out:
#   Cell In[5], line 6
#     print ("pandas:",pd._ _version_ _)
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd 
import numpy as np 
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
print ("pandas:",pd.__version__) 
print("numpy:",np.__version__)
print("matplotlib:", matplotlib.__version__) 
print("seaborn:", sns.__version__)
# Out:
# pandas: 2.3.3
# numpy: 2.3.5
# matplotlib: 3.10.6
# seaborn: 0.13.2

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
path=r"C:\Users\tbend\OneDrive\Desktop\pediatric_research\\"
demo=pd.read_sas(path + "DEMO_L.XPT",format="xport",encoding="utf-8")
bmx=pd.read_sas(path + "BMX_L.XPT", format="xport", encoding="utf-8")
paq=pd.read_sas(path+"PAQ_L.XPT",format="xport",encoding="utf-8")
paqy=pd.read_sas(path+"PAQY_L.XPT",format="xport",encoding="utf-8")
dbq=pd.read_sas(path+"DBQ_L.XPT",format="xport",encoding="utf-8")
print("DEMO_L rows:",len(demo))
print("BMX_L rows:",len(demo))
print("PAQ_L rows:",len(demo))
print("PAQY_L rows:",len(demo))
print("DBQ_L rows:",len(demo))
print ("All files loaded successfully")
# Out:
# DEMO_L rows: 11933
# BMX_L rows: 11933
# PAQ_L rows: 11933
# PAQY_L rows: 11933
# DBQ_L rows: 11933
# All files loaded successfully

# %%
demo.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  130378.0      12.0       2.0       1.0      43.0       NaN       5.0
# 1  130379.0      12.0       2.0       1.0      66.0       NaN       3.0
# 2  130380.0      12.0       2.0       2.0      44.0       NaN       2.0
# 3  130381.0      12.0       2.0       2.0       5.0       NaN       5.0
# 4  130382.0      12.0       2.0       1.0       2.0       NaN       3.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHRGND  DMDHRAGZ  DMDHREDZ  DMDHRMAZ  \
# 0       6.0       2.0       NaN  ...       NaN       NaN       NaN       NaN
# 1       3.0       2.0       NaN  ...       NaN       NaN       NaN       NaN
# 2       2.0       1.0       NaN  ...       NaN       NaN       NaN       NaN
# 3       7.0       1.0      71.0  ...       2.0       2.0       2.0       3.0
# 4       3.0       2.0      34.0  ...       2.0       2.0       3.0       1.0
#
#    DMDHSEDZ      WTINT2YR      WTMEC2YR  SDMVSTRA  SDMVPSU  INDFMPIR
# 0       NaN  50055.450807  54374.463898     173.0      2.0      5.00
# 1       NaN  29087.450605  34084.721548     173.0      2.0      5.00
# 2       NaN  80062.674301  81196.277992     174.0      1.0      1.41
# 3       NaN  38807.268902  55698.607106     182.0      2.0      1.53
# 4       2.0  30607.519774  36434.146346     182.0      2.0      3.60
#
# [5 rows x 27 columns]

# %%
print("Demographics columns:")
print(demo.columns.tolist())
# Out:
# Demographics columns:
# ['SEQN', 'SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN', 'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'RIDEXAGM', 'DMQMILIZ', 'DMDBORN4', 'DMDYRUSR', 'DMDEDUC2', 'DMDMARTZ', 'RIDEXPRG', 'DMDHHSIZ', 'DMDHRGND', 'DMDHRAGZ', 'DMDHREDZ', 'DMDHRMAZ', 'DMDHSEDZ', 'WTINT2YR', 'WTMEC2YR', 'SDMVSTRA', 'SDMVPSU', 'INDFMPIR']

# %%
print("Body Measures Columns:")
print(bmx.columns.tolist())
# Out:
# Body Measures Columns:
# ['SEQN', 'BMDSTATS', 'BMXWT', 'BMIWT', 'BMXRECUM', 'BMIRECUM', 'BMXHEAD', 'BMIHEAD', 'BMXHT', 'BMIHT', 'BMXBMI', 'BMDBMIC', 'BMXLEG', 'BMILEG', 'BMXARML', 'BMIARML', 'BMXARMC', 'BMIARMC', 'BMXWAIST', 'BMIWAIST', 'BMXHIP', 'BMIHIP']

# %%
print("Physical Activity Columns:")
print(paq.columns.tolist())
# Out:
# Physical Activity Columns:
# ['SEQN', 'PAD790Q', 'PAD790U', 'PAD800', 'PAD810Q', 'PAD810U', 'PAD820', 'PAD680']

# %%
print("Physical Activity Youth Colmuns:")
print(paqy.columns.tolist())
# Out:
# Physical Activity Youth Colmuns:
# ['SEQN', 'PAQ706', 'PAQ711']

# %%
print("Diet and Nutrition Columns:")
print(dbq.columns.tolist())
# Out:
# Diet and Nutrition Columns:
# ['SEQN', 'DBQ010', 'DBD030', 'DBD041', 'DBD050', 'DBD055', 'DBD061', 'DBQ073A', 'DBQ073B', 'DBQ073C', 'DBQ073D', 'DBQ073E', 'DBQ073U', 'DBQ301', 'DBQ330', 'DBQ360', 'DBQ370', 'DBD381', 'DBQ390', 'DBQ400', 'DBD411', 'DBQ421', 'DBQ424', 'DBQ930', 'DBQ935', 'DBQ940', 'DBQ945']

# %%
master=demo.merge(bmx,on="SEQN",how="inner")
master=master.merge(paq,on="SEQN",how="inner")
master=master.merge(paqy,on="SEQN",how="inner") 
master=master.merge(dbq,on="SEQN",how="inner")
print("Total rows in master dataset:",len(master))
print("Total columns in master dateset:",len(master.columns))
print("Merge successful")
# Out:
# Total rows in master dataset: 0
# Total columns in master dateset: 83
# Merge successful

# %%
master=demo.merge(bmx,on="SEQN",how="left")
master=master.merge(paq,on="SEQN",how="left")
master=master.merge(paqy,on="SEQN",how="left")
master=master.merge(dbq,on="SEQN",how="left")
print("Total rows in master dataset:",len(master))
print("Total columns in master dataset:",len(master.columns))
print("Merge successful")
# Out:
# Total rows in master dataset: 11933
# Total columns in master dataset: 83
# Merge successful
